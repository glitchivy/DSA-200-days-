# %%
# LC 41 
class Solution(object):
    def firstMissingPositive(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        n=len(nums)
        for i in range(n):
            while nums[i]<=n and nums[i]>0:
                actual_index=nums[i]-1
                if nums[actual_index]!=nums[i]:
                    nums[actual_index],nums[i]=nums[i],nums[actual_index]
                else:
                    break 
        for i in range(n):
            if i+1!=nums[i]:
                return i+1
        return n+1

# %%
# LC 560 
class Solution(object):
    def subarraySum(self, nums, k):
        """
        :type nums: List[int]
        :type k: int
        :rtype: int
        """
        dict={0:1}
        n=len(nums)
        counter_sum=0
        count=0
        for i in range(n):
            counter_sum+=nums[i]
            value=counter_sum-k
            if value in dict:
                count+=dict[value]
            if counter_sum not in dict:
                dict[counter_sum]=1
            else:
                dict[counter_sum]+=1
        return count

# %%
# LC 56 
class Solution(object):
    def merge(self, intervals):
        """
        :type intervals: List[List[int]]
        :rtype: List[List[int]]
        """
        intervals.sort()
        ans=[]
        ans.append(intervals[0])
        for i in range(1,len(intervals)):
            last=ans[-1]
            curr=intervals[i]
            if last[1]>=curr[0]:
                last[1]=max(curr[1],last[1])
            else:
                ans.append(curr)
        return ans
